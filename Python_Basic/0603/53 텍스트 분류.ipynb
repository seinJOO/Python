# %% [markdown]
# ##### 베이즈 정리로 텍스트 분류하기

# %%
# 베이지안 필터(Bayesian filter) :  학습을 많이 시키면 시킬수록 필터의 분류 능력이 오름
#                                 사용자가 따로 키워드 지정을 하지 않아도 스팸 메일을 분류

# 나이브 베이즈 분류(Niive B:yes classifier) 알고리즘 사용

# 베이즈 정리 :  A라는 사건이 B에 속하는지를 판단
#   => 나이브 베이즈 분류는 텍스트 내부에서 단어 출현 비율을 조사하여 해당 텍스트를 어떤 카테고리로 분류하는 것이 적합한지 조사

# %%
import math, sys
from konlpy.tag import Twitter, Okt

class BayesianFilter :
    ''' 베이지안 필터'''
    def __init__(self) :
        self.words = set()          # 출현 단어 기록
        self.word_dict = {}         # 카테고리마다의 출현 횟수 기록
        self.category_dict = {}     # 카테고리 출현 횟수 기록   
    
    ######################### 연산 함수 #############################
    
    # 예측하기
    def predict(self, text) :
        best_category = None
        max_score = -sys.maxsize
        words = self.split(text)        # 텍스트를 형태소 단위로 분해
        score_list = []
        for category in self.category_dict.keys() :     # 카테고리가 카테고리 리스트에 있다면 점수 매기기
            score = self.score(words, category)     
            score_list.append((category, score))
            if score > max_score :
                max_score = score
                best_category = category
        return best_category, score_list
        
    ######################### 형태소 분해 및 계산 함수 #############################    
    
    ### 텍스트 분류 및 학습 - 형태소 단위로 나눈 텍스트를 word_dict와 category_dict에 저장
    def fit(self, text, category) :
        word_list = self.split(text)
        for word in word_list :
            self.inc_word(word, category)
        self.inc_category(category)
    
    # 형태소 단위로 분해하기
    def split(self, text) :
        results = []
        twitter = Okt()
        
        # 단어 기본형 적용
        malist = twitter.pos(text, norm=True, stem=True)
        for word in malist :
            if not word[1] in ['Josa','Eomi', 'Punctuation'] : # 어미/조사/구두점 제외
                results.append(word[0])
        return results
    
    # 단어와 카테고리의 출현 횟수 세기  (단어와 카테고리를 입력받아 word_dict에 저장)
    def inc_word(self, word, category) :
        # 단어를 카테고리에 추가
        if not category in self.word_dict :
            self.word_dict[category] = {}
        if not word in self.word_dict[category] :
            self.word_dict[category][word] = 0
        self.word_dict[category][word] += 1     # 값이 없을 경우 0을 나눌 수 없기 때문에 더해줌 (어차피 효과가 미미함)
        self.words.add(word)
    
    # 카테고리 수집  (카테고리를 입력받아 category_dict에 저장)
    def inc_category(self, category) :
        if not category in self.category_dict :
            self.category_dict[category] = 0
        self.category_dict[category] += 1    
    
    ### 단어 리스트에 점수 매기기
    def score(self, words, category) :
        score = math.log(self.category_prob(category))
        for word in words :
            score += math.log(self.word_prob(word, category))
        return score
        
    # 특정 카테고리의 비율 계산
    def category_prob(self, category):
        sum_categories = sum(self.category_dict.values())
        category_v = self.category_dict[category]
        return category_v / sum_categories
    
    # 카테고리 내부의 단어 출현 비율 계산
    def word_prob(self, word, category):
        n = self.get_word_count(word, category) + 1
        d = sum(self.word_dict[category].values()) + len(self.words)
        return n / d
        
    # 카테고리 내부의 단어 출현 횟수 구하기
    def get_word_count(self, word, category):
        if word in self.word_dict[category]:
            return self.word_dict[category][word]
        else:
            return 0

# %%
# from bayes import BayesianFilter      => 베이지안필터 모듈

bf = BayesianFilter()    # 클래스 호출(객체 생성)

# 텍스트 학습
bf.fit("파격 세일 - 오늘까지만 30% 할인", "광고")
bf.fit("쿠폰 선물 & 무료 배송", "광고")
bf.fit("현대 백화점 세일", "광고")
bf.fit("봄과 함께 찾아온 따뜻한 신제품 소식", "광고")
bf.fit("인기 제품 기간 한정 세일", "광고")
bf.fit("오늘 일정 확인", "중요")
bf.fit("프로젝트 진행 상황 보고", "중요")
bf.fit("계약 잘 부탁드립니다", "중요")
bf.fit("회의 일정이 등록되었습니다.","중요")
bf.fit("오늘 일정이 없습니다.","중요")
bf.fit("재고 확인 부탁드립니다.","중요")

# 예측
pre, scorelist = bf.predict("재고 정리 할인, 무료 배송")
print('결과 =',pre)
print(scorelist)
# Out:
# 결과 = 광고
# [('광고', -19.65728952881656), ('중요', -20.215203675742465)]

# %% [markdown]
# ##### MLP로 텍스트 분류하기

# %%
# 다층 퍼셉트론(Multi Layer Perceptron, MLP) : 입력층과 출력층 사이에 각각 전체 결합하는 은닉층을 넣은 뉴럴 네트워크
#                                            텍스트 데이터를 숫자로 표현할 수 있는 벡터로 변환

### 텍스트 분류 과정
# (1) 텍스트에서 불필요한 품사를 제거한다.
# (2) 사전을 기반으로 단어를 숫자로 변환한다.
# (3) 파일 내부의 단어 출현 비율을 계산한다.
# (4) 데이터를 학습시킨다.
# (5) 테스트 데이터를 넣어 성공률을 확인한다.

# %%
#### 텍스트를 단어로 정제 및 단어를 숫자로 변환하는 코드

import os, glob, json

root_dir = 'data/newstext'
dic_file = root_dir+'/word-dic.json'
data_file = root_dir+'/data.json'
data_file_min = root_dir+'/data-mini.json'

# 데이터 어구를 자르고 ID로 변환하는 함수 - 단어의 ID리스트를 리턴
word_dic = {'_MAX' : 0}
def text_to_ids(text) :
    text = text.strip()
    words = text.split(" ")
    result = []
    for n in words:
        n = n.strip()
        if n == '' : continue
        if not n in word_dic :
            wid = word_dic[n] = word_dic['_MAX']        # 단어에 ID값 부여
            word_dic['_MAX'] += 1
        else : wid = word_dic[n]
        result.append(wid)
    return result     

# 딕셔너리(word_dic)에 단어를 저장하는 함수 - file_to_ids()에서 파일 읽고 text_to_ids()에서 ID값 부여
def register_dic() :
    files = glob.glob(root_dir+'/*/*.wakati', recursive=True)
    for i in files :
        file_to_ids(i)
        
# 파일의 데이터에서 고정 길이 배열 리턴하기 (ID로 변환)
def file_to_ids(fname) :
    with open(fname, 'r', encoding='utf-8') as f :
        text = f.read()
        return text_to_ids(text)        
    
  
        
# 파일 내부의 단어 카운트
def count_file_freq(fname) :
    cnt = [0 for n in range(word_dic['_MAX'])]      # 단어 ID의 개수만큼 0을 채운 리스트 생성
    with open(fname, 'r', encoding='utf-8') as f :
        text = f.read().strip()
        ids = text_to_ids(text)     # 해당 text의 id값을 가져와서 count -> 단어 개수 카운트
        for wid in ids :
            cnt[wid] += 1
    return cnt

# 카테고리마다 파일 읽어오는 함수
def count_freq(limit = 0) :
    X = []      # 단어 개수 카운트 리스트
    Y = []      # 카운트 리스트의 인덱스 역할을 하는 리스트
    max_words = word_dic['_MAX']
    cat_names = []
    for cat in os.listdir(root_dir) :
        cat_dir = root_dir + '/' + cat
        if not os.path.isdir(cat_dir) : continue
        cat_idx = len(cat_names)
        cat_names.append(cat)
        files = glob.glob(cat_dir + '/*.wakati') 
        i = 0
        for path in files :
            print(path)
            cnt = count_file_freq(path)
            X.append(cnt)
            Y.append(cat_idx)
            if limit > 0 :  # limit에 입력값이 있으면 limit까지만 반복
                if i > limit : break    
                i += 1
    return X, Y

# 단어 딕셔너리 만들기
if os.path.exists(dic_file) :
    word_dic = json.load(open(dic_file))
else : 
    register_dic()
    json.dump(word_dic, open(dic_file, 'w', encoding='utf-8'))

# 벡터를 파일로 출력하기
# 테스트 목적의 소규모 데이터 만들기
X, Y = count_freq(20)
json.dump({'X' : X, 'Y' : Y}, open(data_file_min, 'w', encoding='utf-8'))

# 전체 데이터를 기반으로 만들기
X, Y = count_freq()
json.dump({'X': X, 'Y':Y}, open(data_file, 'w', encoding='utf-8'))
print('ok')
# Out:
# data/newstext/100\1.txt.wakati
# data/newstext/100\10.txt.wakati
# data/newstext/100\100.txt.wakati
# data/newstext/100\1000.txt.wakati
# data/newstext/100\1001.txt.wakati
# data/newstext/100\1002.txt.wakati
# data/newstext/100\1003.txt.wakati
# data/newstext/100\1004.txt.wakati
# data/newstext/100\1005.txt.wakati
# data/newstext/100\1006.txt.wakati
# data/newstext/100\1007.txt.wakati
# data/newstext/100\1008.txt.wakati
# data/newstext/100\1009.txt.wakati
# data/newstext/100\101.txt.wakati
# data/newstext/100\1010.txt.wakati
# data/newstext/100\1011.txt.wakati
# data/newstext/100\1012.txt.wakati
# data/newstext/100\1013.txt.wakati
# data/newstext/100\1014.txt.wakati
# data/newstext/100\1015.txt.wakati
# data/newstext/100\1016.txt.wakati
# data/newstext/100\1017.txt.wakati
# data/newstext/101\1.txt.wakati
# data/newstext/101\10.txt.wakati
# data/newstext/101\100.txt.wakati
# data/newstext/101\1000.txt.wakati
# data/newstext/101\1001.txt.wakati
# data/newstext/101\1002.txt.wakati
# data/newstext/101\1003.txt.wakati
# data/newstext/101\1004.txt.wakati
# data/newstext/101\1005.txt.wakati
# data/newstext/101\1006.txt.wakati
# data/newstext/101\1007.txt.wakati
# data/newstext/101\1008.txt.wakati
# data/newstext/101\1009.txt.wakati
# data/newstext/101\101.txt.wakati
# data/newstext/101\1010.txt.wakati
# data/newstext/101\1011.txt.wakati
# data/newstext/101\1012.txt.wakati
# data/newstext/101\1013.txt.wakati
# data/newstext/101\1014.txt.wakati
# data/newstext/101\1015.txt.wakati
# data/newstext/101\1016.txt.wakati
# data/newstext/101\1017.txt.wakati
# data/newstext/102\1.txt.wakati
# data/newstext/102\10.txt.wakati
# data/newstext/102\100.txt.wakati
# data/newstext/102\1000.txt.wakati
# data/newstext/102\1001.txt.wakati
# data/newstext/102\1002.txt.wakati
# data/newstext/102\1003.txt.wakati
# data/newstext/102\1004.txt.wakati
# data/newstext/102\1005.txt.wakati
# data/newstext/102\1006.txt.wakati
# data/newstext/102\1007.txt.wakati
# data/newstext/102\1008.txt.wakati
# data/newstext/102\1009.txt.wakati
# data/newstext/102\101.txt.wakati
# data/newstext/102\1010.txt.wakati
# data/newstext/102\1011.txt.wakati
# data/newstext/102\1012.txt.wakati
# data/newstext/102\1013.txt.wakati
# data/newstext/102\1014.txt.wakati
# data/newstext/102\1015.txt.wakati
# data/newstext/102\1016.txt.wakati
# data/newstext/102\1017.txt.wakati
# data/newstext/103\1.txt.wakati
# data/newstext/103\10.txt.wakati
# data/newstext/103\100.txt.wakati
# data/newstext/103\1000.txt.wakati
# data/newstext/103\1001.txt.wakati
# data/newstext/103\1002.txt.wakati
# data/newstext/103\1003.txt.wakati
# data/newstext/103\1004.txt.wakati
# data/newstext/103\1005.txt.wakati
# data/newstext/103\1006.txt.wakati
# data/newstext/103\1007.txt.wakati
# data/newstext/103\1008.txt.wakati
# data/newstext/103\1009.txt.wakati
# data/newstext/103\101.txt.wakati
# data/newstext/103\1010.txt.wakati
# data/newstext/103\1011.txt.wakati
# data/newstext/103\1012.txt.wakati
# data/newstext/103\1013.txt.wakati
# data/newstext/103\1014.txt.wakati
# data/newstext/103\1015.txt.wakati
# data/newstext/103\1016.txt.wakati
# data/newstext/103\1017.txt.wakati
# data/newstext/104\1.txt.wakati
# data/newstext/104\10.txt.wakati
# data/newstext/104\100.txt.wakati
# data/newstext/104\1000.txt.wakati
# data/newstext/104\1001.txt.wakati
# data/newstext/104\1002.txt.wakati
# data/newstext/104\1003.txt.wakati
# data/newstext/104\1004.txt.wakati
# data/newstext/104\1005.txt.wakati
# data/newstext/104\1006.txt.wakati
# data/newstext/104\1007.txt.wakati
# data/newstext/104\1008.txt.wakati
# data/newstext/104\1009.txt.wakati
# data/newstext/104\101.txt.wakati
# data/newstext/104\1010.txt.wakati
# data/newstext/104\1011.txt.wakati
# data/newstext/104\1012.txt.wakati
# data/newstext/104\1013.txt.wakati
# data/newstext/104\1014.txt.wakati
# data/newstext/104\1015.txt.wakati
# data/newstext/104\1016.txt.wakati
# data/newstext/104\1017.txt.wakati
# data/newstext/105\1.txt.wakati
# data/newstext/105\10.txt.wakati
# data/newstext/105\100.txt.wakati
# data/newstext/105\1000.txt.wakati
# data/newstext/105\1001.txt.wakati
# data/newstext/105\1002.txt.wakati
# data/newstext/105\1003.txt.wakati
# data/newstext/105\1004.txt.wakati
# data/newstext/105\1005.txt.wakati
# data/newstext/105\1006.txt.wakati
# data/newstext/105\1007.txt.wakati
# data/newstext/105\1008.txt.wakati
# data/newstext/105\1009.txt.wakati
# data/newstext/105\101.txt.wakati
# data/newstext/105\1010.txt.wakati
# data/newstext/105\1011.txt.wakati
# data/newstext/105\1012.txt.wakati
# data/newstext/105\1013.txt.wakati
# data/newstext/105\1014.txt.wakati
# data/newstext/105\1015.txt.wakati
# data/newstext/105\1016.txt.wakati
# data/newstext/105\1017.txt.wakati
# data/newstext/100\1.txt.wakati
# data/newstext/100\10.txt.wakati
# data/newstext/100\100.txt.wakati
# data/newstext/100\1000.txt.wakati
# data/newstext/100\1001.txt.wakati
# data/newstext/100\1002.txt.wakati
# data/newstext/100\1003.txt.wakati
# data/newstext/100\1004.txt.wakati
# data/newstext/100\1005.txt.wakati
# data/newstext/100\1006.txt.wakati
# data/newstext/100\1007.txt.wakati
# data/newstext/100\1008.txt.wakati
# data/newstext/100\1009.txt.wakati
# data/newstext/100\101.txt.wakati
# data/newstext/100\1010.txt.wakati
# data/newstext/100\1011.txt.wakati
# data/newstext/100\1012.txt.wakati
# data/newstext/100\1013.txt.wakati
# data/newstext/100\1014.txt.wakati
# data/newstext/100\1015.txt.wakati
# data/newstext/100\1016.txt.wakati
# data/newstext/100\1017.txt.wakati
# data/newstext/100\1018.txt.wakati
# data/newstext/100\1019.txt.wakati
# data/newstext/100\102.txt.wakati
# data/newstext/100\1020.txt.wakati
# data/newstext/100\1021.txt.wakati
# data/newstext/100\1022.txt.wakati
# data/newstext/100\1023.txt.wakati
# data/newstext/100\1024.txt.wakati
# data/newstext/100\1025.txt.wakati
# data/newstext/100\1026.txt.wakati
# data/newstext/100\1027.txt.wakati
# data/newstext/100\1028.txt.wakati
# data/newstext/100\1029.txt.wakati
# data/newstext/100\103.txt.wakati
# data/newstext/100\1030.txt.wakati
# data/newstext/100\1031.txt.wakati
# data/newstext/100\1032.txt.wakati
# data/newstext/100\1033.txt.wakati
# data/newstext/100\1034.txt.wakati
# data/newstext/100\1035.txt.wakati
# data/newstext/100\1036.txt.wakati
# data/newstext/100\1037.txt.wakati
# data/newstext/100\1038.txt.wakati
# data/newstext/100\1039.txt.wakati
# data/newstext/100\104.txt.wakati
# data/newstext/100\1040.txt.wakati
# data/newstext/100\1041.txt.wakati
# data/newstext/100\1042.txt.wakati
# data/newstext/100\1043.txt.wakati
# data/newstext/100\1044.txt.wakati
# data/newstext/100\1045.txt.wakati
# data/newstext/100\1046.txt.wakati
# data/newstext/100\1047.txt.wakati
# data/newstext/100\1048.txt.wakati
# data/newstext/100\1049.txt.wakati
# data/newstext/100\105.txt.wakati
# data/newstext/100\1050.txt.wakati
# data/newstext/100\1051.txt.wakati
# data/newstext/100\1052.txt.wakati
# data/newstext/100\1053.txt.wakati
# data/newstext/100\1054.txt.wakati
# data/newstext/100\1055.txt.wakati
# data/newstext/100\1056.txt.wakati
# data/newstext/100\1057.txt.wakati
# data/newstext/100\1058.txt.wakati
# data/newstext/100\1059.txt.wakati
# data/newstext/100\106.txt.wakati
# data/newstext/100\1060.txt.wakati
# data/newstext/100\1061.txt.wakati
# data/newstext/100\1062.txt.wakati
# data/newstext/100\1063.txt.wakati
# data/newstext/100\1064.txt.wakati
# data/newstext/100\1065.txt.wakati
# data/newstext/100\1066.txt.wakati
# data/newstext/100\1067.txt.wakati
# data/newstext/100\1068.txt.wakati
# data/newstext/100\1069.txt.wakati
# data/newstext/100\107.txt.wakati
# data/newstext/100\1070.txt.wakati
# data/newstext/100\1071.txt.wakati
# data/newstext/100\1072.txt.wakati
# data/newstext/100\1073.txt.wakati
# data/newstext/100\1074.txt.wakati
# data/newstext/100\1075.txt.wakati
# data/newstext/100\1076.txt.wakati
# data/newstext/100\1077.txt.wakati
# data/newstext/100\1078.txt.wakati
# data/newstext/100\1079.txt.wakati
# data/newstext/100\108.txt.wakati
# data/newstext/100\1080.txt.wakati
# data/newstext/100\1081.txt.wakati
# data/newstext/100\1082.txt.wakati
# data/newstext/100\1083.txt.wakati
# data/newstext/100\1084.txt.wakati
# data/newstext/100\1085.txt.wakati
# data/newstext/100\1086.txt.wakati
# data/newstext/100\1087.txt.wakati
# data/newstext/100\1088.txt.wakati
# data/newstext/100\1089.txt.wakati
# data/newstext/100\109.txt.wakati
# data/newstext/100\1090.txt.wakati
# data/newstext/100\1091.txt.wakati
# data/newstext/100\1092.txt.wakati
# data/newstext/100\1093.txt.wakati
# data/newstext/100\1094.txt.wakati
# data/newstext/100\1095.txt.wakati
# data/newstext/100\1096.txt.wakati
# data/newstext/100\1097.txt.wakati
# data/newstext/100\1098.txt.wakati
# data/newstext/100\1099.txt.wakati
# data/newstext/100\11.txt.wakati
# data/newstext/100\110.txt.wakati
# data/newstext/100\1100.txt.wakati
# data/newstext/100\1101.txt.wakati
# data/newstext/100\1102.txt.wakati
# data/newstext/100\1103.txt.wakati
# data/newstext/100\1104.txt.wakati
# data/newstext/100\1105.txt.wakati
# data/newstext/100\1106.txt.wakati
# data/newstext/100\1107.txt.wakati
# data/newstext/100\1108.txt.wakati
# data/newstext/100\1109.txt.wakati
# data/newstext/100\111.txt.wakati
# data/newstext/100\1110.txt.wakati
# data/newstext/100\1111.txt.wakati
# data/newstext/100\1112.txt.wakati
# data/newstext/100\1113.txt.wakati
# data/newstext/100\1114.txt.wakati
# data/newstext/100\1115.txt.wakati
# data/newstext/100\1116.txt.wakati
# data/newstext/100\1117.txt.wakati
# data/newstext/100\1118.txt.wakati
# data/newstext/100\1119.txt.wakati
# data/newstext/100\112.txt.wakati
# data/newstext/100\1120.txt.wakati
# data/newstext/100\1121.txt.wakati
# data/newstext/100\1122.txt.wakati
# data/newstext/100\1123.txt.wakati
# data/newstext/100\1124.txt.wakati
# data/newstext/100\1125.txt.wakati
# data/newstext/100\1126.txt.wakati
# data/newstext/100\1127.txt.wakati
# data/newstext/100\1128.txt.wakati
# data/newstext/100\1129.txt.wakati
# data/newstext/100\113.txt.wakati
# data/newstext/100\1130.txt.wakati
# data/newstext/100\1131.txt.wakati
# data/newstext/100\1132.txt.wakati
# data/newstext/100\1133.txt.wakati
# data/newstext/100\1134.txt.wakati
# data/newstext/100\1135.txt.wakati
# data/newstext/100\1136.txt.wakati
# data/newstext/100\1137.txt.wakati
# data/newstext/100\1138.txt.wakati
# data/newstext/100\1139.txt.wakati
# data/newstext/100\114.txt.wakati
# data/newstext/100\1140.txt.wakati
# data/newstext/100\1141.txt.wakati
# data/newstext/100\1142.txt.wakati
# data/newstext/100\1143.txt.wakati
# data/newstext/100\1144.txt.wakati
# data/newstext/100\1145.txt.wakati
# data/newstext/100\1146.txt.wakati
# data/newstext/100\1147.txt.wakati
# data/newstext/100\1148.txt.wakati
# data/newstext/100\1149.txt.wakati
# data/newstext/100\115.txt.wakati
# data/newstext/100\1150.txt.wakati
# data/newstext/100\1151.txt.wakati
# data/newstext/100\1152.txt.wakati
# data/newstext/100\1153.txt.wakati
# data/newstext/100\1154.txt.wakati
# data/newstext/100\1155.txt.wakati
# data/newstext/100\1156.txt.wakati
# data/newstext/100\1157.txt.wakati
# data/newstext/100\1158.txt.wakati
# data/newstext/100\1159.txt.wakati
# data/newstext/100\116.txt.wakati
# data/newstext/100\1160.txt.wakati
# data/newstext/100\1161.txt.wakati
# data/newstext/100\1162.txt.wakati
# data/newstext/100\1163.txt.wakati
# data/newstext/100\1164.txt.wakati
# data/newstext/100\1165.txt.wakati
# data/newstext/100\1166.txt.wakati
# data/newstext/100\1167.txt.wakati
# data/newstext/100\1168.txt.wakati
# data/newstext/100\1169.txt.wakati
# data/newstext/100\117.txt.wakati
# data/newstext/100\1170.txt.wakati
# data/newstext/100\1171.txt.wakati
# data/newstext/100\1172.txt.wakati
# data/newstext/100\1173.txt.wakati
# data/newstext/100\1174.txt.wakati
# data/newstext/100\1175.txt.wakati
# data/newstext/100\1176.txt.wakati
# data/newstext/100\1177.txt.wakati
# data/newstext/100\1178.txt.wakati
# data/newstext/100\1179.txt.wakati
# data/newstext/100\118.txt.wakati
# data/newstext/100\1180.txt.wakati
# data/newstext/100\1181.txt.wakati
# data/newstext/100\1182.txt.wakati
# data/newstext/100\1183.txt.wakati
# data/newstext/100\1184.txt.wakati
# data/newstext/100\1185.txt.wakati
# data/newstext/100\1186.txt.wakati
# data/newstext/100\1187.txt.wakati
# data/newstext/100\1188.txt.wakati
# data/newstext/100\1189.txt.wakati
# data/newstext/100\119.txt.wakati
# data/newstext/100\1190.txt.wakati
# data/newstext/100\1191.txt.wakati
# data/newstext/100\1192.txt.wakati
# data/newstext/100\1193.txt.wakati
# data/newstext/100\1194.txt.wakati
# data/newstext/100\1195.txt.wakati
# data/newstext/100\1196.txt.wakati
# data/newstext/100\1197.txt.wakati
# data/newstext/100\1198.txt.wakati
# data/newstext/100\1199.txt.wakati
# data/newstext/100\12.txt.wakati
# data/newstext/100\120.txt.wakati
# data/newstext/100\1200.txt.wakati
# data/newstext/100\1201.txt.wakati
# data/newstext/100\1202.txt.wakati
# data/newstext/100\1203.txt.wakati
# data/newstext/100\1204.txt.wakati
# data/newstext/100\1205.txt.wakati
# data/newstext/100\1206.txt.wakati
# data/newstext/100\1207.txt.wakati
# data/newstext/100\1208.txt.wakati
# data/newstext/100\1209.txt.wakati
# data/newstext/100\121.txt.wakati
# data/newstext/100\1210.txt.wakati
# data/newstext/100\1211.txt.wakati
# data/newstext/100\1212.txt.wakati
# data/newstext/100\1213.txt.wakati
# data/newstext/100\1214.txt.wakati
# data/newstext/100\1215.txt.wakati
# data/newstext/100\1216.txt.wakati
# data/newstext/100\1217.txt.wakati
# data/newstext/100\1218.txt.wakati
# data/newstext/100\1219.txt.wakati
# data/newstext/100\122.txt.wakati
# data/newstext/100\1220.txt.wakati
# data/newstext/100\1221.txt.wakati
# data/newstext/100\1222.txt.wakati
# data/newstext/100\1223.txt.wakati
# data/newstext/100\1224.txt.wakati
# data/newstext/100\1225.txt.wakati
# data/newstext/100\1226.txt.wakati
# data/newstext/100\1227.txt.wakati
# data/newstext/100\1228.txt.wakati
# data/newstext/100\1229.txt.wakati
# data/newstext/100\123.txt.wakati
# data/newstext/100\1230.txt.wakati
# data/newstext/100\1231.txt.wakati
# data/newstext/100\1232.txt.wakati
# data/newstext/100\1233.txt.wakati
# data/newstext/100\1234.txt.wakati
# data/newstext/100\1235.txt.wakati
# data/newstext/100\1236.txt.wakati
# data/newstext/100\1237.txt.wakati
# data/newstext/100\1238.txt.wakati
# data/newstext/100\1239.txt.wakati
# data/newstext/100\124.txt.wakati
# data/newstext/100\1240.txt.wakati
# data/newstext/100\1241.txt.wakati
# data/newstext/100\1242.txt.wakati
# data/newstext/100\1243.txt.wakati
# data/newstext/100\1244.txt.wakati
# data/newstext/100\1245.txt.wakati
# data/newstext/100\1246.txt.wakati
# data/newstext/100\1247.txt.wakati
# data/newstext/100\1248.txt.wakati
# data/newstext/100\1249.txt.wakati
# data/newstext/100\125.txt.wakati
# data/newstext/100\1250.txt.wakati
# data/newstext/100\1251.txt.wakati
# data/newstext/100\1252.txt.wakati
# data/newstext/100\1253.txt.wakati
# data/newstext/100\1254.txt.wakati
# data/newstext/100\1255.txt.wakati
# data/newstext/100\1256.txt.wakati
# data/newstext/100\1257.txt.wakati
# data/newstext/100\1258.txt.wakati
# data/newstext/100\1259.txt.wakati
# data/newstext/100\126.txt.wakati
# data/newstext/100\1260.txt.wakati
# data/newstext/100\1261.txt.wakati
# data/newstext/100\1262.txt.wakati
# data/newstext/100\1263.txt.wakati
# data/newstext/100\1264.txt.wakati
# data/newstext/100\1265.txt.wakati
# data/newstext/100\1266.txt.wakati
# data/newstext/100\1267.txt.wakati
# data/newstext/100\1268.txt.wakati
# data/newstext/100\1269.txt.wakati
# data/newstext/100\127.txt.wakati
# data/newstext/100\1270.txt.wakati
# data/newstext/100\1271.txt.wakati
# data/newstext/100\1272.txt.wakati
# data/newstext/100\1273.txt.wakati
# data/newstext/100\1274.txt.wakati
# data/newstext/100\1275.txt.wakati
# data/newstext/100\1276.txt.wakati
# data/newstext/100\1277.txt.wakati
# data/newstext/100\1278.txt.wakati
# data/newstext/100\1279.txt.wakati
# data/newstext/100\128.txt.wakati
# data/newstext/100\1280.txt.wakati
# data/newstext/100\1281.txt.wakati
# data/newstext/100\1282.txt.wakati
# data/newstext/100\1283.txt.wakati
# data/newstext/100\1284.txt.wakati
# data/newstext/100\1285.txt.wakati
# data/newstext/100\1286.txt.wakati
# data/newstext/100\1287.txt.wakati
# data/newstext/100\1288.txt.wakati
# data/newstext/100\1289.txt.wakati
# data/newstext/100\129.txt.wakati
# data/newstext/100\1290.txt.wakati
# data/newstext/100\1291.txt.wakati
# data/newstext/100\1292.txt.wakati
# data/newstext/100\1293.txt.wakati
# data/newstext/100\1294.txt.wakati
# data/newstext/100\1295.txt.wakati
# data/newstext/100\1296.txt.wakati
# data/newstext/100\1297.txt.wakati
# data/newstext/100\1298.txt.wakati
# data/newstext/100\1299.txt.wakati
# data/newstext/100\13.txt.wakati
# data/newstext/100\130.txt.wakati
# data/newstext/100\1300.txt.wakati
# data/newstext/100\1301.txt.wakati
# data/newstext/100\1302.txt.wakati
# data/newstext/100\1303.txt.wakati
# data/newstext/100\1304.txt.wakati
# data/newstext/100\1305.txt.wakati
# data/newstext/100\1306.txt.wakati
# data/newstext/100\1307.txt.wakati
# data/newstext/100\1308.txt.wakati
# data/newstext/100\1309.txt.wakati
# data/newstext/100\131.txt.wakati
# data/newstext/100\1310.txt.wakati
# data/newstext/100\1311.txt.wakati
# data/newstext/100\1312.txt.wakati
# data/newstext/100\1313.txt.wakati
# data/newstext/100\1314.txt.wakati
# data/newstext/100\1315.txt.wakati
# data/newstext/100\1316.txt.wakati
# data/newstext/100\1317.txt.wakati
# data/newstext/100\1318.txt.wakati
# data/newstext/100\1319.txt.wakati
# data/newstext/100\132.txt.wakati
# data/newstext/100\1320.txt.wakati
# data/newstext/100\1321.txt.wakati
# data/newstext/100\1322.txt.wakati
# data/newstext/100\1323.txt.wakati
# data/newstext/100\1324.txt.wakati
# data/newstext/100\1325.txt.wakati
# data/newstext/100\1326.txt.wakati
# data/newstext/100\1327.txt.wakati
# data/newstext/100\1328.txt.wakati
# data/newstext/100\1329.txt.wakati
# data/newstext/100\133.txt.wakati
# data/newstext/100\1330.txt.wakati
# data/newstext/100\1331.txt.wakati
# data/newstext/100\1332.txt.wakati
# data/newstext/100\1333.txt.wakati
# data/newstext/100\1334.txt.wakati
# data/newstext/100\1335.txt.wakati
# data/newstext/100\1336.txt.wakati
# data/newstext/100\1337.txt.wakati
# data/newstext/100\1338.txt.wakati
# data/newstext/100\1339.txt.wakati
# data/newstext/100\134.txt.wakati
# data/newstext/100\1340.txt.wakati
# data/newstext/100\1341.txt.wakati
# data/newstext/100\1342.txt.wakati
# data/newstext/100\1343.txt.wakati
# data/newstext/100\1344.txt.wakati
# data/newstext/100\1345.txt.wakati
# data/newstext/100\1346.txt.wakati
# data/newstext/100\1347.txt.wakati
# data/newstext/100\1348.txt.wakati
# data/newstext/100\1349.txt.wakati
# data/newstext/100\135.txt.wakati
# data/newstext/100\1350.txt.wakati
# data/newstext/100\1351.txt.wakati
# data/newstext/100\1352.txt.wakati
# data/newstext/100\1353.txt.wakati
# data/newstext/100\1354.txt.wakati
# data/newstext/100\1355.txt.wakati
# data/newstext/100\1356.txt.wakati
# data/newstext/100\1357.txt.wakati
# data/newstext/100\1358.txt.wakati
# data/newstext/100\1359.txt.wakati
# data/newstext/100\136.txt.wakati
# data/newstext/100\1360.txt.wakati
# data/newstext/100\1361.txt.wakati
# data/newstext/100\1362.txt.wakati
# data/newstext/100\1363.txt.wakati
# data/newstext/100\1364.txt.wakati
# data/newstext/100\1365.txt.wakati
# data/newstext/100\1366.txt.wakati
# data/newstext/100\1367.txt.wakati
# data/newstext/100\1368.txt.wakati
# data/newstext/100\1369.txt.wakati
# data/newstext/100\137.txt.wakati
# data/newstext/100\1370.txt.wakati
# data/newstext/100\1371.txt.wakati
# data/newstext/100\1372.txt.wakati
# data/newstext/100\1373.txt.wakati
# data/newstext/100\1374.txt.wakati
# data/newstext/100\1375.txt.wakati
# data/newstext/100\1376.txt.wakati
# data/newstext/100\1377.txt.wakati
# data/newstext/100\1378.txt.wakati
# data/newstext/100\1379.txt.wakati
# data/newstext/100\138.txt.wakati
# data/newstext/100\1380.txt.wakati
# data/newstext/100\1381.txt.wakati
# data/newstext/100\1382.txt.wakati
# data/newstext/100\1383.txt.wakati
# data/newstext/100\1384.txt.wakati
# data/newstext/100\1385.txt.wakati
# data/newstext/100\1386.txt.wakati
# data/newstext/100\1387.txt.wakati
# data/newstext/100\1388.txt.wakati
# data/newstext/100\1389.txt.wakati
# data/newstext/100\139.txt.wakati
# data/newstext/100\1390.txt.wakati
# data/newstext/100\1391.txt.wakati
# data/newstext/100\1392.txt.wakati
# data/newstext/100\1393.txt.wakati
# data/newstext/100\1394.txt.wakati
# data/newstext/100\1395.txt.wakati
# data/newstext/100\1396.txt.wakati
# data/newstext/100\1397.txt.wakati
# data/newstext/100\1398.txt.wakati
# data/newstext/100\1399.txt.wakati
# data/newstext/100\14.txt.wakati
# data/newstext/100\140.txt.wakati
# data/newstext/100\1400.txt.wakati
# data/newstext/100\1401.txt.wakati
# data/newstext/100\1402.txt.wakati
# data/newstext/100\1403.txt.wakati
# data/newstext/100\1404.txt.wakati
# data/newstext/100\1405.txt.wakati
# data/newstext/100\1406.txt.wakati
# data/newstext/100\1407.txt.wakati
# data/newstext/100\1408.txt.wakati
# data/newstext/100\1409.txt.wakati
# data/newstext/100\141.txt.wakati
# data/newstext/100\1410.txt.wakati
# data/newstext/100\1411.txt.wakati
# data/newstext/100\1412.txt.wakati
# data/newstext/100\1413.txt.wakati
# data/newstext/100\1414.txt.wakati
# data/newstext/100\1415.txt.wakati
# data/newstext/100\1416.txt.wakati
# data/newstext/100\1417.txt.wakati
# data/newstext/100\1418.txt.wakati
# data/newstext/100\1419.txt.wakati
# data/newstext/100\142.txt.wakati
# data/newstext/100\1420.txt.wakati
# data/newstext/100\1421.txt.wakati
# data/newstext/100\1422.txt.wakati
# data/newstext/100\1423.txt.wakati
# data/newstext/100\1424.txt.wakati
# data/newstext/100\1425.txt.wakati
# data/newstext/100\1426.txt.wakati
# data/newstext/100\1427.txt.wakati
# data/newstext/100\1428.txt.wakati
# data/newstext/100\1429.txt.wakati
# data/newstext/100\143.txt.wakati
# data/newstext/100\1430.txt.wakati
# data/newstext/100\1431.txt.wakati
# data/newstext/100\1432.txt.wakati
# data/newstext/100\1433.txt.wakati
# data/newstext/100\1434.txt.wakati
# data/newstext/100\1435.txt.wakati
# data/newstext/100\1436.txt.wakati
# data/newstext/100\1437.txt.wakati
# data/newstext/100\1438.txt.wakati
# data/newstext/100\1439.txt.wakati
# data/newstext/100\144.txt.wakati
# data/newstext/100\1440.txt.wakati
# data/newstext/100\1441.txt.wakati
# data/newstext/100\1442.txt.wakati
# data/newstext/100\1443.txt.wakati
# data/newstext/100\1444.txt.wakati
# data/newstext/100\1445.txt.wakati
# data/newstext/100\1446.txt.wakati
# data/newstext/100\1447.txt.wakati
# data/newstext/100\1448.txt.wakati
# data/newstext/100\1449.txt.wakati
# data/newstext/100\145.txt.wakati
# data/newstext/100\1450.txt.wakati
# data/newstext/100\1451.txt.wakati
# data/newstext/100\1452.txt.wakati
# data/newstext/100\1453.txt.wakati
# data/newstext/100\1454.txt.wakati
# data/newstext/100\1455.txt.wakati
# data/newstext/100\1456.txt.wakati
# data/newstext/100\1457.txt.wakati
# data/newstext/100\1458.txt.wakati
# data/newstext/100\1459.txt.wakati
# data/newstext/100\146.txt.wakati
# data/newstext/100\1460.txt.wakati
# data/newstext/100\1461.txt.wakati
# data/newstext/100\1462.txt.wakati
# data/newstext/100\1463.txt.wakati
# data/newstext/100\1464.txt.wakati
# data/newstext/100\1465.txt.wakati
# data/newstext/100\1466.txt.wakati
# data/newstext/100\1467.txt.wakati
# data/newstext/100\1468.txt.wakati
# data/newstext/100\1469.txt.wakati
# data/newstext/100\147.txt.wakati
# data/newstext/100\1470.txt.wakati
# data/newstext/100\1471.txt.wakati
# data/newstext/100\1472.txt.wakati
# data/newstext/100\1473.txt.wakati
# data/newstext/100\1474.txt.wakati
# data/newstext/100\1475.txt.wakati
# data/newstext/100\1476.txt.wakati
# data/newstext/100\1477.txt.wakati
# data/newstext/100\1478.txt.wakati
# data/newstext/100\1479.txt.wakati
# data/newstext/100\148.txt.wakati
# data/newstext/100\1480.txt.wakati
# data/newstext/100\1481.txt.wakati
# data/newstext/100\1482.txt.wakati
# data/newstext/100\1483.txt.wakati
# data/newstext/100\1484.txt.wakati
# data/newstext/100\1485.txt.wakati
# data/newstext/100\1486.txt.wakati
# data/newstext/100\1487.txt.wakati
# data/newstext/100\1488.txt.wakati
# data/newstext/100\1489.txt.wakati
# data/newstext/100\149.txt.wakati
# data/newstext/100\1490.txt.wakati
# data/newstext/100\1491.txt.wakati
# data/newstext/100\1492.txt.wakati
# data/newstext/100\1493.txt.wakati
# data/newstext/100\1494.txt.wakati
# data/newstext/100\1495.txt.wakati
# data/newstext/100\1496.txt.wakati
# data/newstext/100\1497.txt.wakati
# data/newstext/100\1498.txt.wakati
# data/newstext/100\1499.txt.wakati
# data/newstext/100\15.txt.wakati
# data/newstext/100\150.txt.wakati
# data/newstext/100\1500.txt.wakati
# data/newstext/100\1501.txt.wakati
# data/newstext/100\1502.txt.wakati
# data/newstext/100\1503.txt.wakati
# data/newstext/100\1504.txt.wakati
# data/newstext/100\1505.txt.wakati
# data/newstext/100\1506.txt.wakati
# data/newstext/100\1507.txt.wakati
# data/newstext/100\1508.txt.wakati
# data/newstext/100\1509.txt.wakati
# data/newstext/100\151.txt.wakati
# data/newstext/100\1510.txt.wakati
# data/newstext/100\1511.txt.wakati
# data/newstext/100\1512.txt.wakati
# data/newstext/100\1513.txt.wakati
# data/newstext/100\1514.txt.wakati
# data/newstext/100\1515.txt.wakati
# data/newstext/100\1516.txt.wakati
# data/newstext/100\1517.txt.wakati
# data/newstext/100\1518.txt.wakati
# data/newstext/100\1519.txt.wakati
# data/newstext/100\152.txt.wakati
# data/newstext/100\1520.txt.wakati
# data/newstext/100\1521.txt.wakati
# data/newstext/100\1522.txt.wakati
# data/newstext/100\1523.txt.wakati
# data/newstext/100\1524.txt.wakati
# data/newstext/100\1525.txt.wakati
# data/newstext/100\1526.txt.wakati
# data/newstext/100\1527.txt.wakati
# data/newstext/100\1528.txt.wakati
# data/newstext/100\1529.txt.wakati
# data/newstext/100\153.txt.wakati
# data/newstext/100\1530.txt.wakati
# data/newstext/100\1531.txt.wakati
# data/newstext/100\1532.txt.wakati
# data/newstext/100\1533.txt.wakati
# data/newstext/100\1534.txt.wakati
# data/newstext/100\1535.txt.wakati
# data/newstext/100\1536.txt.wakati
# data/newstext/100\1537.txt.wakati
# data/newstext/100\1538.txt.wakati
# data/newstext/100\1539.txt.wakati
# data/newstext/100\154.txt.wakati
# data/newstext/100\1540.txt.wakati
# data/newstext/100\1541.txt.wakati
# data/newstext/100\1542.txt.wakati
# data/newstext/100\1543.txt.wakati
# data/newstext/100\1544.txt.wakati
# data/newstext/100\1545.txt.wakati
# data/newstext/100\1546.txt.wakati
# data/newstext/100\1547.txt.wakati
# data/newstext/100\1548.txt.wakati
# data/newstext/100\1549.txt.wakati
# data/newstext/100\155.txt.wakati
# data/newstext/100\1550.txt.wakati
# data/newstext/100\1551.txt.wakati
# data/newstext/100\1552.txt.wakati
# data/newstext/100\1553.txt.wakati
# data/newstext/100\1554.txt.wakati
# data/newstext/100\1555.txt.wakati
# data/newstext/100\1556.txt.wakati
# data/newstext/100\1557.txt.wakati
# data/newstext/100\1558.txt.wakati
# data/newstext/100\1559.txt.wakati
# data/newstext/100\156.txt.wakati
# data/newstext/100\1560.txt.wakati
# data/newstext/100\1561.txt.wakati
# data/newstext/100\1562.txt.wakati
# data/newstext/100\1563.txt.wakati
# data/newstext/100\1564.txt.wakati
# data/newstext/100\1565.txt.wakati
# data/newstext/100\1566.txt.wakati
# data/newstext/100\1567.txt.wakati
# data/newstext/100\1568.txt.wakati
# data/newstext/100\1569.txt.wakati
# data/newstext/100\157.txt.wakati
# data/newstext/100\1570.txt.wakati
# data/newstext/100\1571.txt.wakati
# data/newstext/100\1572.txt.wakati
# data/newstext/100\1573.txt.wakati
# data/newstext/100\1574.txt.wakati
# data/newstext/100\1575.txt.wakati
# data/newstext/100\1576.txt.wakati
# data/newstext/100\1577.txt.wakati
# data/newstext/100\1578.txt.wakati
# data/newstext/100\1579.txt.wakati
# data/newstext/100\158.txt.wakati
# data/newstext/100\1580.txt.wakati
# data/newstext/100\1581.txt.wakati
# data/newstext/100\1582.txt.wakati
# data/newstext/100\1583.txt.wakati
# data/newstext/100\1584.txt.wakati
# data/newstext/100\1585.txt.wakati
# data/newstext/100\1586.txt.wakati
# data/newstext/100\1587.txt.wakati
# data/newstext/100\1588.txt.wakati
# data/newstext/100\1589.txt.wakati
# data/newstext/100\159.txt.wakati
# data/newstext/100\1590.txt.wakati
# data/newstext/100\1591.txt.wakati
# data/newstext/100\1592.txt.wakati
# data/newstext/100\1593.txt.wakati
# data/newstext/100\1594.txt.wakati
# data/newstext/100\1595.txt.wakati
# data/newstext/100\1596.txt.wakati
# data/newstext/100\1597.txt.wakati
# data/newstext/100\1598.txt.wakati
# data/newstext/100\1599.txt.wakati
# data/newstext/100\16.txt.wakati
# data/newstext/100\160.txt.wakati
# data/newstext/100\1600.txt.wakati
# data/newstext/100\1601.txt.wakati
# data/newstext/100\1602.txt.wakati
# data/newstext/100\1603.txt.wakati
# data/newstext/100\1604.txt.wakati
# data/newstext/100\1605.txt.wakati
# data/newstext/100\1606.txt.wakati
# data/newstext/100\1607.txt.wakati
# data/newstext/100\1608.txt.wakati
# data/newstext/100\1609.txt.wakati
# data/newstext/100\161.txt.wakati
# data/newstext/100\1610.txt.wakati
# data/newstext/100\1611.txt.wakati
# data/newstext/100\1612.txt.wakati
# data/newstext/100\1613.txt.wakati
# data/newstext/100\1614.txt.wakati
# data/newstext/100\1615.txt.wakati
# data/newstext/100\1616.txt.wakati
# data/newstext/100\1617.txt.wakati
# data/newstext/100\1618.txt.wakati
# data/newstext/100\1619.txt.wakati
# data/newstext/100\162.txt.wakati
# data/newstext/100\1620.txt.wakati
# data/newstext/100\1621.txt.wakati
# data/newstext/100\1622.txt.wakati
# data/newstext/100\1623.txt.wakati
# data/newstext/100\1624.txt.wakati
# data/newstext/100\1625.txt.wakati
# data/newstext/100\1626.txt.wakati
# data/newstext/100\1627.txt.wakati
# data/newstext/100\1628.txt.wakati
# data/newstext/100\1629.txt.wakati
# data/newstext/100\163.txt.wakati
# data/newstext/100\1630.txt.wakati
# data/newstext/100\1631.txt.wakati
# data/newstext/100\1632.txt.wakati
# data/newstext/100\1633.txt.wakati
# data/newstext/100\1634.txt.wakati
# data/newstext/100\1635.txt.wakati
# data/newstext/100\1636.txt.wakati
# data/newstext/100\1637.txt.wakati
# data/newstext/100\1638.txt.wakati
# data/newstext/100\1639.txt.wakati
# data/newstext/100\164.txt.wakati
# data/newstext/100\1640.txt.wakati
# data/newstext/100\1641.txt.wakati
# data/newstext/100\1642.txt.wakati
# data/newstext/100\1643.txt.wakati
# data/newstext/100\1644.txt.wakati
# data/newstext/100\1645.txt.wakati
# data/newstext/100\1646.txt.wakati
# data/newstext/100\1647.txt.wakati
# data/newstext/100\1648.txt.wakati
# data/newstext/100\1649.txt.wakati
# data/newstext/100\165.txt.wakati
# data/newstext/100\1650.txt.wakati
# data/newstext/100\1651.txt.wakati
# data/newstext/100\1652.txt.wakati
# data/newstext/100\1653.txt.wakati
# data/newstext/100\1654.txt.wakati
# data/newstext/100\1655.txt.wakati
# data/newstext/100\1656.txt.wakati
# data/newstext/100\1657.txt.wakati
# data/newstext/100\1658.txt.wakati
# data/newstext/100\1659.txt.wakati
# data/newstext/100\166.txt.wakati
# data/newstext/100\1660.txt.wakati
# data/newstext/100\1661.txt.wakati
# data/newstext/100\1662.txt.wakati
# data/newstext/100\1663.txt.wakati
# data/newstext/100\1664.txt.wakati
# data/newstext/100\1665.txt.wakati
# data/newstext/100\1666.txt.wakati
# data/newstext/100\1667.txt.wakati
# data/newstext/100\1668.txt.wakati
# data/newstext/100\1669.txt.wakati
# data/newstext/100\167.txt.wakati
# data/newstext/100\1670.txt.wakati
# data/newstext/100\1671.txt.wakati
# data/newstext/100\1672.txt.wakati
# data/newstext/100\1673.txt.wakati
# data/newstext/100\1674.txt.wakati
# data/newstext/100\1675.txt.wakati
# data/newstext/100\1676.txt.wakati
# data/newstext/100\1677.txt.wakati
# data/newstext/100\1678.txt.wakati
# data/newstext/100\1679.txt.wakati
# data/newstext/100\168.txt.wakati
# data/newstext/100\1680.txt.wakati
# data/newstext/100\1681.txt.wakati
# data/newstext/100\1682.txt.wakati
# data/newstext/100\1683.txt.wakati
# data/newstext/100\1684.txt.wakati
# data/newstext/100\1685.txt.wakati
# data/newstext/100\1686.txt.wakati
# data/newstext/100\1687.txt.wakati
# data/newstext/100\1688.txt.wakati
# data/newstext/100\1689.txt.wakati
# data/newstext/100\169.txt.wakati
# data/newstext/100\1690.txt.wakati
# data/newstext/100\1691.txt.wakati
# data/newstext/100\1692.txt.wakati
# data/newstext/100\1693.txt.wakati
# data/newstext/100\1694.txt.wakati
# data/newstext/100\1695.txt.wakati
# data/newstext/100\1696.txt.wakati
# data/newstext/100\1697.txt.wakati
# data/newstext/100\1698.txt.wakati
# data/newstext/100\1699.txt.wakati
# data/newstext/100\17.txt.wakati
# data/newstext/100\170.txt.wakati
# data/newstext/100\1700.txt.wakati
# data/newstext/100\1701.txt.wakati
# data/newstext/100\1702.txt.wakati
# data/newstext/100\1703.txt.wakati
# data/newstext/100\1704.txt.wakati
# data/newstext/100\1705.txt.wakati
# data/newstext/100\1706.txt.wakati
# data/newstext/100\1707.txt.wakati
# data/newstext/100\1708.txt.wakati
# data/newstext/100\1709.txt.wakati
# data/newstext/100\171.txt.wakati
# data/newstext/100\1710.txt.wakati
# data/newstext/100\1711.txt.wakati
# data/newstext/100\1712.txt.wakati
# data/newstext/100\1713.txt.wakati
# data/newstext/100\1714.txt.wakati
# data/newstext/100\1715.txt.wakati
# data/newstext/100\1716.txt.wakati
# data/newstext/100\1717.txt.wakati
# data/newstext/100\1718.txt.wakati
# data/newstext/100\1719.txt.wakati
# data/newstext/100\172.txt.wakati
# data/newstext/100\1720.txt.wakati
# data/newstext/100\1721.txt.wakati
# data/newstext/100\1722.txt.wakati
# data/newstext/100\1723.txt.wakati
# data/newstext/100\1724.txt.wakati
# data/newstext/100\1725.txt.wakati
# data/newstext/100\1726.txt.wakati
# data/newstext/100\1727.txt.wakati
# data/newstext/100\1728.txt.wakati
# data/newstext/100\1729.txt.wakati
# data/newstext/100\173.txt.wakati
# data/newstext/100\1730.txt.wakati
# data/newstext/100\1731.txt.wakati
# data/newstext/100\1732.txt.wakati
# data/newstext/100\1733.txt.wakati
# data/newstext/100\1734.txt.wakati
# data/newstext/100\1735.txt.wakati
# data/newstext/100\1736.txt.wakati
# data/newstext/100\1737.txt.wakati
# data/newstext/100\1738.txt.wakati
# data/newstext/100\1739.txt.wakati
# data/newstext/100\174.txt.wakati
# data/newstext/100\1740.txt.wakati
# data/newstext/100\1741.txt.wakati
# data/newstext/100\1742.txt.wakati
# data/newstext/100\1743.txt.wakati
# data/newstext/100\1744.txt.wakati
# data/newstext/100\1745.txt.wakati
# data/newstext/100\1746.txt.wakati
# data/newstext/100\1747.txt.wakati
# data/newstext/100\1748.txt.wakati
# data/newstext/100\1749.txt.wakati
# data/newstext/100\175.txt.wakati
# data/newstext/100\1750.txt.wakati
# data/newstext/100\1751.txt.wakati
# data/newstext/100\1752.txt.wakati
# data/newstext/100\1753.txt.wakati
# data/newstext/100\1754.txt.wakati
# data/newstext/100\1755.txt.wakati
# data/newstext/100\1756.txt.wakati
# data/newstext/100\1757.txt.wakati
# data/newstext/100\1758.txt.wakati
# data/newstext/100\1759.txt.wakati
# data/newstext/100\176.txt.wakati
# data/newstext/100\1760.txt.wakati
# data/newstext/100\1761.txt.wakati
# data/newstext/100\1762.txt.wakati
# data/newstext/100\1763.txt.wakati
# data/newstext/100\1764.txt.wakati
# data/newstext/100\1765.txt.wakati
# data/newstext/100\1766.txt.wakati
# data/newstext/100\1767.txt.wakati
# data/newstext/100\1768.txt.wakati
# data/newstext/100\1769.txt.wakati
# data/newstext/100\177.txt.wakati
# data/newstext/100\1770.txt.wakati
# data/newstext/100\1771.txt.wakati
# data/newstext/100\1772.txt.wakati
# data/newstext/100\1773.txt.wakati
# data/newstext/100\1774.txt.wakati
# data/newstext/100\1775.txt.wakati
# data/newstext/100\1776.txt.wakati
# data/newstext/100\1777.txt.wakati
# data/newstext/100\1778.txt.wakati
# data/newstext/100\1779.txt.wakati
# data/newstext/100\178.txt.wakati
# data/newstext/100\1780.txt.wakati
# data/newstext/100\1781.txt.wakati
# data/newstext/100\1782.txt.wakati
# data/newstext/100\1783.txt.wakati
# data/newstext/100\1784.txt.wakati
# data/newstext/100\1785.txt.wakati
# data/newstext/100\1786.txt.wakati
# data/newstext/100\1787.txt.wakati
# data/newstext/100\1788.txt.wakati
# data/newstext/100\1789.txt.wakati
# data/newstext/100\179.txt.wakati
# data/newstext/100\1790.txt.wakati
# data/newstext/100\1791.txt.wakati
# data/newstext/100\1792.txt.wakati
# data/newstext/100\1793.txt.wakati
# data/newstext/100\1794.txt.wakati
# data/newstext/100\1795.txt.wakati
# data/newstext/100\1796.txt.wakati
# data/newstext/100\1797.txt.wakati
# data/newstext/100\1798.txt.wakati
# data/newstext/100\1799.txt.wakati
# data/newstext/100\18.txt.wakati
# data/newstext/100\180.txt.wakati
# data/newstext/100\1800.txt.wakati
# data/newstext/100\1801.txt.wakati
# data/newstext/100\1802.txt.wakati
# data/newstext/100\1803.txt.wakati
# data/newstext/100\1804.txt.wakati
# data/newstext/100\1805.txt.wakati
# data/newstext/100\1806.txt.wakati
# data/newstext/100\1807.txt.wakati
# data/newstext/100\1808.txt.wakati
# data/newstext/100\1809.txt.wakati
# data/newstext/100\181.txt.wakati
# data/newstext/100\1810.txt.wakati
# data/newstext/100\1811.txt.wakati
# data/newstext/100\1812.txt.wakati
# data/newstext/100\1813.txt.wakati
# data/newstext/100\1814.txt.wakati
# data/newstext/100\1815.txt.wakati
# data/newstext/100\1816.txt.wakati
# data/newstext/100\1817.txt.wakati
# data/newstext/100\1818.txt.wakati
# data/newstext/100\1819.txt.wakati
# data/newstext/100\182.txt.wakati
# data/newstext/100\1820.txt.wakati
# data/newstext/100\1821.txt.wakati
# data/newstext/100\1822.txt.wakati
# data/newstext/100\1823.txt.wakati
# data/newstext/100\1824.txt.wakati
# data/newstext/100\1825.txt.wakati
# data/newstext/100\1826.txt.wakati
# data/newstext/100\1827.txt.wakati
# data/newstext/100\1828.txt.wakati
# data/newstext/100\1829.txt.wakati
# data/newstext/100\183.txt.wakati
# data/newstext/100\1830.txt.wakati
# data/newstext/100\1831.txt.wakati
# data/newstext/100\1832.txt.wakati
# data/newstext/100\1833.txt.wakati
# data/newstext/100\1834.txt.wakati
# data/newstext/100\1835.txt.wakati
# data/newstext/100\1836.txt.wakati
# data/newstext/100\1837.txt.wakati
# data/newstext/100\1838.txt.wakati
# data/newstext/100\1839.txt.wakati
# data/newstext/100\184.txt.wakati
# data/newstext/100\1840.txt.wakati
# data/newstext/100\1841.txt.wakati
# data/newstext/100\1842.txt.wakati
# data/newstext/100\1843.txt.wakati
# data/newstext/100\1844.txt.wakati
# data/newstext/100\1845.txt.wakati
# data/newstext/100\1846.txt.wakati
# data/newstext/100\1847.txt.wakati
# data/newstext/100\1848.txt.wakati
# data/newstext/100\1849.txt.wakati
# data/newstext/100\185.txt.wakati
# data/newstext/100\1850.txt.wakati
# data/newstext/100\1851.txt.wakati
# data/newstext/100\1852.txt.wakati
# data/newstext/100\1853.txt.wakati
# data/newstext/100\1854.txt.wakati
# data/newstext/100\1855.txt.wakati
# data/newstext/100\1856.txt.wakati
# data/newstext/100\1857.txt.wakati
# data/newstext/100\1858.txt.wakati
# data/newstext/100\1859.txt.wakati
# data/newstext/100\186.txt.wakati
# data/newstext/100\1860.txt.wakati
# data/newstext/100\1861.txt.wakati
# data/newstext/100\1862.txt.wakati
# data/newstext/100\1863.txt.wakati
# data/newstext/100\1864.txt.wakati
# data/newstext/100\1865.txt.wakati
# data/newstext/100\1866.txt.wakati
# data/newstext/100\1867.txt.wakati
# data/newstext/100\1868.txt.wakati
# data/newstext/100\1869.txt.wakati
# data/newstext/100\187.txt.wakati
# data/newstext/100\1870.txt.wakati
# data/newstext/100\1871.txt.wakati
# data/newstext/100\1872.txt.wakati
# data/newstext/100\1873.txt.wakati
# data/newstext/100\1874.txt.wakati
# data/newstext/100\1875.txt.wakati
# data/newstext/100\1876.txt.wakati
# data/newstext/100\1877.txt.wakati
# data/newstext/100\1878.txt.wakati
# data/newstext/100\1879.txt.wakati
# data/newstext/100\188.txt.wakati
# data/newstext/100\1880.txt.wakati
# data/newstext/100\1881.txt.wakati
# data/newstext/100\1882.txt.wakati
# data/newstext/100\1883.txt.wakati
# data/newstext/100\1884.txt.wakati
# data/newstext/100\1885.txt.wakati
# data/newstext/100\1886.txt.wakati
# data/newstext/100\1887.txt.wakati
# data/newstext/100\1888.txt.wakati
# data/newstext/100\1889.txt.wakati
# data/newstext/100\189.txt.wakati
# data/newstext/100\1890.txt.wakati
# data/newstext/100\1891.txt.wakati
# data/newstext/100\1892.txt.wakati
# data/newstext/100\1893.txt.wakati
# data/newstext/100\1894.txt.wakati
# data/newstext/100\1895.txt.wakati
# data/newstext/100\1896.txt.wakati
# data/newstext/100\1897.txt.wakati
# data/newstext/100\1898.txt.wakati
# data/newstext/100\1899.txt.wakati
# data/newstext/100\19.txt.wakati
# data/newstext/100\190.txt.wakati
# data/newstext/100\1900.txt.wakati
# data/newstext/100\1901.txt.wakati
# data/newstext/100\1902.txt.wakati
# data/newstext/100\1903.txt.wakati
# data/newstext/100\1904.txt.wakati
# data/newstext/100\1905.txt.wakati
# data/newstext/100\1906.txt.wakati
# data/newstext/100\1907.txt.wakati
# data/newstext/100\1908.txt.wakati
# data/newstext/100\1909.txt.wakati
# data/newstext/100\191.txt.wakati
# data/newstext/100\1910.txt.wakati
# data/newstext/100\1911.txt.wakati
# data/newstext/100\1912.txt.wakati
# data/newstext/100\1913.txt.wakati
# data/newstext/100\1914.txt.wakati
# data/newstext/100\1915.txt.wakati
# data/newstext/100\1916.txt.wakati
# data/newstext/100\1917.txt.wakati
# data/newstext/100\1918.txt.wakati
# data/newstext/100\1919.txt.wakati
# data/newstext/100\192.txt.wakati
# data/newstext/100\1920.txt.wakati
# data/newstext/100\1921.txt.wakati
# data/newstext/100\1922.txt.wakati
# data/newstext/100\1923.txt.wakati
# data/newstext/100\1924.txt.wakati
# data/newstext/100\1925.txt.wakati
# data/newstext/100\1926.txt.wakati
# data/newstext/100\1927.txt.wakati
# data/newstext/100\1928.txt.wakati
# data/newstext/100\1929.txt.wakati
# data/newstext/100\193.txt.wakati
# data/newstext/100\1930.txt.wakati
# data/newstext/100\1931.txt.wakati
# data/newstext/100\1932.txt.wakati
# data/newstext/100\1933.txt.wakati
# data/newstext/100\1934.txt.wakati
# data/newstext/100\1935.txt.wakati
# data/newstext/100\1936.txt.wakati
# data/newstext/100\1937.txt.wakati
# data/newstext/100\1938.txt.wakati
# data/newstext/100\1939.txt.wakati
# data/newstext/100\194.txt.wakati
# data/newstext/100\1940.txt.wakati
# data/newstext/100\1941.txt.wakati
# data/newstext/100\1942.txt.wakati
# data/newstext/100\1943.txt.wakati
# data/newstext/100\1944.txt.wakati
# data/newstext/100\1945.txt.wakati
# data/newstext/100\1946.txt.wakati
# data/newstext/100\1947.txt.wakati
# data/newstext/100\1948.txt.wakati
# data/newstext/100\1949.txt.wakati
# data/newstext/100\195.txt.wakati
# data/newstext/100\1950.txt.wakati
# data/newstext/100\1951.txt.wakati
# data/newstext/100\1952.txt.wakati
# data/newstext/100\1953.txt.wakati
# data/newstext/100\1954.txt.wakati
# data/newstext/100\1955.txt.wakati
# data/newstext/100\1956.txt.wakati
# data/newstext/100\1957.txt.wakati
# data/newstext/100\1958.txt.wakati
# data/newstext/100\1959.txt.wakati
# data/newstext/100\196.txt.wakati
# data/newstext/100\1960.txt.wakati
# data/newstext/100\1961.txt.wakati
# data/newstext/100\1962.txt.wakati
# data/newstext/100\1963.txt.wakati
# data/newstext/100\1964.txt.wakati
# data/newstext/100\1965.txt.wakati
# data/newstext/100\1966.txt.wakati
# data/newstext/100\1967.txt.wakati
# data/newstext/100\1968.txt.wakati
# data/newstext/100\1969.txt.wakati
# data/newstext/100\197.txt.wakati
# data/newstext/100\1970.txt.wakati
# data/newstext/100\1971.txt.wakati
# data/newstext/100\1972.txt.wakati
# data/newstext/100\1973.txt.wakati
# data/newstext/100\1974.txt.wakati
# data/newstext/100\1975.txt.wakati
# data/newstext/100\1976.txt.wakati
# data/newstext/100\1977.txt.wakati
# data/newstext/100\1978.txt.wakati
# data/newstext/100\1979.txt.wakati
# data/newstext/100\198.txt.wakati
# data/newstext/100\1980.txt.wakati
# data/newstext/100\1981.txt.wakati
# data/newstext/100\1982.txt.wakati
# data/newstext/100\1983.txt.wakati
# data/newstext/100\1984.txt.wakati
# data/newstext/100\1985.txt.wakati
# data/newstext/100\1986.txt.wakati
# data/newstext/100\1987.txt.wakati
# data/newstext/100\1988.txt.wakati
# data/newstext/100\1989.txt.wakati
# data/newstext/100\199.txt.wakati
# data/newstext/100\1990.txt.wakati
# data/newstext/100\1991.txt.wakati
# data/newstext/100\1992.txt.wakati
# data/newstext/100\1993.txt.wakati
# data/newstext/100\1994.txt.wakati
# data/newstext/100\1995.txt.wakati
# data/newstext/100\1996.txt.wakati
# data/newstext/100\1997.txt.wakati
# data/newstext/100\1998.txt.wakati
# data/newstext/100\1999.txt.wakati
# data/newstext/100\2.txt.wakati
# data/newstext/100\20.txt.wakati
# data/newstext/100\200.txt.wakati
# data/newstext/100\2000.txt.wakati
# data/newstext/100\2001.txt.wakati
# data/newstext/100\2002.txt.wakati
# data/newstext/100\2003.txt.wakati
# data/newstext/100\2004.txt.wakati
# data/newstext/100\2005.txt.wakati
# data/newstext/100\2006.txt.wakati
# data/newstext/100\2007.txt.wakati
# data/newstext/100\2008.txt.wakati
# data/newstext/100\2009.txt.wakati
# data/newstext/100\201.txt.wakati
# data/newstext/100\2010.txt.wakati
# data/newstext/100\2011.txt.wakati
# data/newstext/100\2012.txt.wakati
# data/newstext/100\2013.txt.wakati
# data/newstext/100\2014.txt.wakati
# data/newstext/100\2015.txt.wakati
# data/newstext/100\2016.txt.wakati
# data/newstext/100\2017.txt.wakati
# data/newstext/100\2018.txt.wakati
# data/newstext/100\2019.txt.wakati
# data/newstext/100\202.txt.wakati
# data/newstext/100\2020.txt.wakati
# data/newstext/100\2021.txt.wakati
# data/newstext/100\2022.txt.wakati
# data/newstext/100\2023.txt.wakati
# data/newstext/100\2024.txt.wakati
# data/newstext/100\2025.txt.wakati
# data/newstext/100\2026.txt.wakati
# data/newstext/100\2027.txt.wakati
# data/newstext/100\2028.txt.wakati
# data/newstext/100\2029.txt.wakati
# data/newstext/100\203.txt.wakati
# data/newstext/100\2030.txt.wakati
# data/newstext/100\2031.txt.wakati
# data/newstext/100\2032.txt.wakati
# data/newstext/100\2033.txt.wakati
# data/newstext/100\2034.txt.wakati
# data/newstext/100\2035.txt.wakati
# data/newstext/100\2036.txt.wakati
# data/newstext/100\2037.txt.wakati
# data/newstext/100\2038.txt.wakati
# data/newstext/100\2039.txt.wakati
# data/newstext/100\204.txt.wakati
# data/newstext/100\2040.txt.wakati
# data/newstext/100\2041.txt.wakati
# data/newstext/100\2042.txt.wakati
# data/newstext/100\2043.txt.wakati
# data/newstext/100\2044.txt.wakati
# data/newstext/100\2045.txt.wakati
# data/newstext/100\2046.txt.wakati
# data/newstext/100\2047.txt.wakati
# data/newstext/100\2048.txt.wakati
# data/newstext/100\2049.txt.wakati
# data/newstext/100\205.txt.wakati
# data/newstext/100\2050.txt.wakati
# data/newstext/100\2051.txt.wakati
# data/newstext/100\2052.txt.wakati
# data/newstext/100\2053.txt.wakati
# data/newstext/100\2054.txt.wakati
# data/newstext/100\2055.txt.wakati
# data/newstext/100\2056.txt.wakati
# data/newstext/100\2057.txt.wakati
# data/newstext/100\2058.txt.wakati
# data/newstext/100\2059.txt.wakati
# data/newstext/100\206.txt.wakati
# data/newstext/100\2060.txt.wakati
# data/newstext/100\2061.txt.wakati
# data/newstext/100\2062.txt.wakati
# data/newstext/100\2063.txt.wakati
# data/newstext/100\2064.txt.wakati
# data/newstext/100\2065.txt.wakati
# data/newstext/100\2066.txt.wakati
# data/newstext/100\2067.txt.wakati
# data/newstext/100\2068.txt.wakati
# data/newstext/100\2069.txt.wakati
# data/newstext/100\207.txt.wakati
# data/newstext/100\2070.txt.wakati
# data/newstext/100\2071.txt.wakati
# data/newstext/100\2072.txt.wakati
# data/newstext/100\2073.txt.wakati
# data/newstext/100\2074.txt.wakati
# data/newstext/100\2075.txt.wakati
# data/newstext/100\2076.txt.wakati
# data/newstext/100\2077.txt.wakati
# data/newstext/100\2078.txt.wakati
# data/newstext/100\2079.txt.wakati
# data/newstext/100\208.txt.wakati
# data/newstext/100\2080.txt.wakati
# data/newstext/100\2081.txt.wakati
# data/newstext/100\2082.txt.wakati
# data/newstext/100\2083.txt.wakati
# data/newstext/100\2084.txt.wakati
# data/newstext/100\2085.txt.wakati
# data/newstext/100\2086.txt.wakati
# data/newstext/100\2087.txt.wakati
# data/newstext/100\2088.txt.wakati
# data/newstext/100\2089.txt.wakati
# data/newstext/100\209.txt.wakati
# data/newstext/100\2090.txt.wakati
# data/newstext/100\2091.txt.wakati
# data/newstext/100\2092.txt.wakati
# data/newstext/100\2093.txt.wakati
# data/newstext/100\2094.txt.wakati
# data/newstext/100\2095.txt.wakati
# data/newstext/100\2096.txt.wakati
# data/newstext/100\2097.txt.wakati
# data/newstext/100\2098.txt.wakati
# data/newstext/100\2099.txt.wakati
# data/newstext/100\21.txt.wakati
# data/newstext/100\210.txt.wakati
# data/newstext/100\2100.txt.wakati
# data/newstext/100\2101.txt.wakati
# data/newstext/100\2102.txt.wakati
# data/newstext/100\2103.txt.wakati
# data/newstext/100\2104.txt.wakati
# data/newstext/100\2105.txt.wakati
# data/newstext/100\2106.txt.wakati
# data/newstext/100\2107.txt.wakati
# data/newstext/100\2108.txt.wakati
# data/newstext/100\2109.txt.wakati
# data/newstext/100\211.txt.wakati
# data/newstext/100\2110.txt.wakati
# data/newstext/100\2111.txt.wakati
# data/newstext/100\2112.txt.wakati
# data/newstext/100\2113.txt.wakati
# data/newstext/100\2114.txt.wakati
# data/newstext/100\2115.txt.wakati
# data/newstext/100\2116.txt.wakati
# data/newstext/100\2117.txt.wakati
# data/newstext/100\2118.txt.wakati
# data/newstext/100\2119.txt.wakati
# data/newstext/100\212.txt.wakati
# data/newstext/100\2120.txt.wakati
# data/newstext/100\2121.txt.wakati
# data/newstext/100\2122.txt.wakati
# data/newstext/100\2123.txt.wakati
# data/newstext/100\2124.txt.wakati
# data/newstext/100\2125.txt.wakati
# data/newstext/100\2126.txt.wakati
# data/newstext/100\2127.txt.wakati
# data/newstext/100\2128.txt.wakati
# data/newstext/100\2129.txt.wakati
# data/newstext/100\213.txt.wakati
# data/newstext/100\2130.txt.wakati
# data/newstext/100\2131.txt.wakati
# data/newstext/100\2132.txt.wakati
# data/newstext/100\2133.txt.wakati
# data/newstext/100\2134.txt.wakati
# data/newstext/100\2135.txt.wakati
# data/newstext/100\2136.txt.wakati
# data/newstext/100\2137.txt.wakati
# data/newstext/100\2138.txt.wakati
# data/newstext/100\2139.txt.wakati
# data/newstext/100\214.txt.wakati
# data/newstext/100\2140.txt.wakati
# data/newstext/100\2141.txt.wakati
# data/newstext/100\2142.txt.wakati
# data/newstext/100\2143.txt.wakati
# data/newstext/100\2144.txt.wakati
# data/newstext/100\2145.txt.wakati
# data/newstext/100\2146.txt.wakati
# data/newstext/100\2147.txt.wakati
# data/newstext/100\2148.txt.wakati
# data/newstext/100\2149.txt.wakati
# data/newstext/100\215.txt.wakati
# data/newstext/100\2150.txt.wakati
# data/newstext/100\2151.txt.wakati
# data/newstext/100\2152.txt.wakati
# data/newstext/100\2153.txt.wakati
# data/newstext/100\2154.txt.wakati
# ...
# data/newstext/105\561.txt.wakati
# data/newstext/105\562.txt.wakati
# data/newstext/105\563.txt.wakati
# data/newstext/105\564.txt.wakati
# data/newstext/105\565.txt.wakati
# data/newstext/105\566.txt.wakati
# data/newstext/105\567.txt.wakati
# data/newstext/105\568.txt.wakati
# data/newstext/105\569.txt.wakati
# data/newstext/105\57.txt.wakati
# data/newstext/105\570.txt.wakati
# data/newstext/105\571.txt.wakati
# data/newstext/105\572.txt.wakati
# data/newstext/105\573.txt.wakati
# data/newstext/105\574.txt.wakati
# data/newstext/105\575.txt.wakati
# data/newstext/105\576.txt.wakati
# data/newstext/105\577.txt.wakati
# data/newstext/105\578.txt.wakati
# data/newstext/105\579.txt.wakati
# data/newstext/105\58.txt.wakati
# data/newstext/105\580.txt.wakati
# data/newstext/105\581.txt.wakati
# data/newstext/105\582.txt.wakati
# data/newstext/105\583.txt.wakati
# data/newstext/105\584.txt.wakati
# data/newstext/105\585.txt.wakati
# data/newstext/105\586.txt.wakati
# data/newstext/105\587.txt.wakati
# data/newstext/105\588.txt.wakati
# data/newstext/105\589.txt.wakati
# data/newstext/105\59.txt.wakati
# data/newstext/105\590.txt.wakati
# data/newstext/105\591.txt.wakati
# data/newstext/105\592.txt.wakati
# data/newstext/105\593.txt.wakati
# data/newstext/105\594.txt.wakati
# data/newstext/105\595.txt.wakati
# data/newstext/105\596.txt.wakati
# data/newstext/105\597.txt.wakati
# data/newstext/105\598.txt.wakati
# data/newstext/105\599.txt.wakati
# data/newstext/105\6.txt.wakati
# data/newstext/105\60.txt.wakati
# data/newstext/105\600.txt.wakati
# data/newstext/105\601.txt.wakati
# data/newstext/105\602.txt.wakati
# data/newstext/105\603.txt.wakati
# data/newstext/105\604.txt.wakati
# data/newstext/105\605.txt.wakati
# data/newstext/105\606.txt.wakati
# data/newstext/105\607.txt.wakati
# data/newstext/105\608.txt.wakati
# data/newstext/105\609.txt.wakati
# data/newstext/105\61.txt.wakati
# data/newstext/105\610.txt.wakati
# data/newstext/105\611.txt.wakati
# data/newstext/105\612.txt.wakati
# data/newstext/105\613.txt.wakati
# data/newstext/105\614.txt.wakati
# data/newstext/105\615.txt.wakati
# data/newstext/105\616.txt.wakati
# data/newstext/105\617.txt.wakati
# data/newstext/105\618.txt.wakati
# data/newstext/105\619.txt.wakati
# data/newstext/105\62.txt.wakati
# data/newstext/105\620.txt.wakati
# data/newstext/105\621.txt.wakati
# data/newstext/105\622.txt.wakati
# data/newstext/105\623.txt.wakati
# data/newstext/105\624.txt.wakati
# data/newstext/105\625.txt.wakati
# data/newstext/105\626.txt.wakati
# data/newstext/105\627.txt.wakati
# data/newstext/105\628.txt.wakati
# data/newstext/105\629.txt.wakati
# data/newstext/105\63.txt.wakati
# data/newstext/105\630.txt.wakati
# data/newstext/105\631.txt.wakati
# data/newstext/105\632.txt.wakati
# data/newstext/105\633.txt.wakati
# data/newstext/105\634.txt.wakati
# data/newstext/105\635.txt.wakati
# data/newstext/105\636.txt.wakati
# data/newstext/105\637.txt.wakati
# data/newstext/105\638.txt.wakati
# data/newstext/105\639.txt.wakati
# data/newstext/105\64.txt.wakati
# data/newstext/105\640.txt.wakati
# data/newstext/105\641.txt.wakati
# data/newstext/105\642.txt.wakati
# data/newstext/105\643.txt.wakati
# data/newstext/105\644.txt.wakati
# data/newstext/105\645.txt.wakati
# data/newstext/105\646.txt.wakati
# data/newstext/105\647.txt.wakati
# data/newstext/105\648.txt.wakati
# data/newstext/105\649.txt.wakati
# data/newstext/105\65.txt.wakati
# data/newstext/105\650.txt.wakati
# data/newstext/105\651.txt.wakati
# data/newstext/105\652.txt.wakati
# data/newstext/105\653.txt.wakati
# data/newstext/105\654.txt.wakati
# data/newstext/105\655.txt.wakati
# data/newstext/105\656.txt.wakati
# data/newstext/105\657.txt.wakati
# data/newstext/105\658.txt.wakati
# data/newstext/105\659.txt.wakati
# data/newstext/105\66.txt.wakati
# data/newstext/105\660.txt.wakati
# data/newstext/105\661.txt.wakati
# data/newstext/105\662.txt.wakati
# data/newstext/105\663.txt.wakati
# data/newstext/105\664.txt.wakati
# data/newstext/105\665.txt.wakati
# data/newstext/105\666.txt.wakati
# data/newstext/105\667.txt.wakati
# data/newstext/105\668.txt.wakati
# data/newstext/105\669.txt.wakati
# data/newstext/105\67.txt.wakati
# data/newstext/105\670.txt.wakati
# data/newstext/105\671.txt.wakati
# data/newstext/105\672.txt.wakati
# data/newstext/105\673.txt.wakati
# data/newstext/105\674.txt.wakati
# data/newstext/105\675.txt.wakati
# data/newstext/105\676.txt.wakati
# data/newstext/105\677.txt.wakati
# data/newstext/105\678.txt.wakati
# data/newstext/105\679.txt.wakati
# data/newstext/105\68.txt.wakati
# data/newstext/105\680.txt.wakati
# data/newstext/105\681.txt.wakati
# data/newstext/105\682.txt.wakati
# data/newstext/105\683.txt.wakati
# data/newstext/105\684.txt.wakati
# data/newstext/105\685.txt.wakati
# data/newstext/105\686.txt.wakati
# data/newstext/105\687.txt.wakati
# data/newstext/105\688.txt.wakati
# data/newstext/105\689.txt.wakati
# data/newstext/105\69.txt.wakati
# data/newstext/105\690.txt.wakati
# data/newstext/105\691.txt.wakati
# data/newstext/105\692.txt.wakati
# data/newstext/105\693.txt.wakati
# data/newstext/105\694.txt.wakati
# data/newstext/105\695.txt.wakati
# data/newstext/105\696.txt.wakati
# data/newstext/105\697.txt.wakati
# data/newstext/105\698.txt.wakati
# data/newstext/105\699.txt.wakati
# data/newstext/105\7.txt.wakati
# data/newstext/105\70.txt.wakati
# data/newstext/105\700.txt.wakati
# data/newstext/105\701.txt.wakati
# data/newstext/105\702.txt.wakati
# data/newstext/105\703.txt.wakati
# data/newstext/105\704.txt.wakati
# data/newstext/105\705.txt.wakati
# data/newstext/105\706.txt.wakati
# data/newstext/105\707.txt.wakati
# data/newstext/105\708.txt.wakati
# data/newstext/105\709.txt.wakati
# data/newstext/105\71.txt.wakati
# data/newstext/105\710.txt.wakati
# data/newstext/105\711.txt.wakati
# data/newstext/105\712.txt.wakati
# data/newstext/105\713.txt.wakati
# data/newstext/105\714.txt.wakati
# data/newstext/105\715.txt.wakati
# data/newstext/105\716.txt.wakati
# data/newstext/105\717.txt.wakati
# data/newstext/105\718.txt.wakati
# data/newstext/105\719.txt.wakati
# data/newstext/105\72.txt.wakati
# data/newstext/105\720.txt.wakati
# data/newstext/105\721.txt.wakati
# data/newstext/105\722.txt.wakati
# data/newstext/105\723.txt.wakati
# data/newstext/105\724.txt.wakati
# data/newstext/105\725.txt.wakati
# data/newstext/105\726.txt.wakati
# data/newstext/105\727.txt.wakati
# data/newstext/105\728.txt.wakati
# data/newstext/105\729.txt.wakati
# data/newstext/105\73.txt.wakati
# data/newstext/105\730.txt.wakati
# data/newstext/105\731.txt.wakati
# data/newstext/105\732.txt.wakati
# data/newstext/105\733.txt.wakati
# data/newstext/105\734.txt.wakati
# data/newstext/105\735.txt.wakati
# data/newstext/105\736.txt.wakati
# data/newstext/105\737.txt.wakati
# data/newstext/105\738.txt.wakati
# data/newstext/105\739.txt.wakati
# data/newstext/105\74.txt.wakati
# data/newstext/105\740.txt.wakati
# data/newstext/105\741.txt.wakati
# data/newstext/105\742.txt.wakati
# data/newstext/105\743.txt.wakati
# data/newstext/105\744.txt.wakati
# data/newstext/105\745.txt.wakati
# data/newstext/105\746.txt.wakati
# data/newstext/105\747.txt.wakati
# data/newstext/105\748.txt.wakati
# data/newstext/105\749.txt.wakati
# data/newstext/105\75.txt.wakati
# data/newstext/105\750.txt.wakati
# data/newstext/105\751.txt.wakati
# data/newstext/105\752.txt.wakati
# data/newstext/105\753.txt.wakati
# data/newstext/105\754.txt.wakati
# data/newstext/105\755.txt.wakati
# data/newstext/105\756.txt.wakati
# data/newstext/105\757.txt.wakati
# data/newstext/105\758.txt.wakati
# data/newstext/105\759.txt.wakati
# data/newstext/105\76.txt.wakati
# data/newstext/105\760.txt.wakati
# data/newstext/105\761.txt.wakati
# data/newstext/105\762.txt.wakati
# data/newstext/105\763.txt.wakati
# data/newstext/105\764.txt.wakati
# data/newstext/105\765.txt.wakati
# data/newstext/105\766.txt.wakati
# data/newstext/105\767.txt.wakati
# data/newstext/105\768.txt.wakati
# data/newstext/105\769.txt.wakati
# data/newstext/105\77.txt.wakati
# data/newstext/105\770.txt.wakati
# data/newstext/105\771.txt.wakati
# data/newstext/105\772.txt.wakati
# data/newstext/105\773.txt.wakati
# data/newstext/105\774.txt.wakati
# data/newstext/105\775.txt.wakati
# data/newstext/105\776.txt.wakati
# data/newstext/105\777.txt.wakati
# data/newstext/105\778.txt.wakati
# data/newstext/105\779.txt.wakati
# data/newstext/105\78.txt.wakati
# data/newstext/105\780.txt.wakati
# data/newstext/105\781.txt.wakati
# data/newstext/105\782.txt.wakati
# data/newstext/105\783.txt.wakati
# data/newstext/105\784.txt.wakati
# data/newstext/105\785.txt.wakati
# data/newstext/105\786.txt.wakati
# data/newstext/105\787.txt.wakati
# data/newstext/105\788.txt.wakati
# data/newstext/105\789.txt.wakati
# data/newstext/105\79.txt.wakati
# data/newstext/105\790.txt.wakati
# data/newstext/105\791.txt.wakati
# data/newstext/105\792.txt.wakati
# data/newstext/105\793.txt.wakati
# data/newstext/105\794.txt.wakati
# data/newstext/105\795.txt.wakati
# data/newstext/105\796.txt.wakati
# data/newstext/105\797.txt.wakati
# data/newstext/105\798.txt.wakati
# data/newstext/105\799.txt.wakati
# data/newstext/105\8.txt.wakati
# data/newstext/105\80.txt.wakati
# data/newstext/105\800.txt.wakati
# data/newstext/105\801.txt.wakati
# data/newstext/105\802.txt.wakati
# data/newstext/105\803.txt.wakati
# data/newstext/105\804.txt.wakati
# data/newstext/105\805.txt.wakati
# data/newstext/105\806.txt.wakati
# data/newstext/105\807.txt.wakati
# data/newstext/105\808.txt.wakati
# data/newstext/105\809.txt.wakati
# data/newstext/105\81.txt.wakati
# data/newstext/105\810.txt.wakati
# data/newstext/105\811.txt.wakati
# data/newstext/105\812.txt.wakati
# data/newstext/105\813.txt.wakati
# data/newstext/105\814.txt.wakati
# data/newstext/105\815.txt.wakati
# data/newstext/105\816.txt.wakati
# data/newstext/105\817.txt.wakati
# data/newstext/105\818.txt.wakati
# data/newstext/105\819.txt.wakati
# data/newstext/105\82.txt.wakati
# data/newstext/105\820.txt.wakati
# data/newstext/105\821.txt.wakati
# data/newstext/105\822.txt.wakati
# data/newstext/105\823.txt.wakati
# data/newstext/105\824.txt.wakati
# data/newstext/105\825.txt.wakati
# data/newstext/105\826.txt.wakati
# data/newstext/105\827.txt.wakati
# data/newstext/105\828.txt.wakati
# data/newstext/105\829.txt.wakati
# data/newstext/105\83.txt.wakati
# data/newstext/105\830.txt.wakati
# data/newstext/105\831.txt.wakati
# data/newstext/105\832.txt.wakati
# data/newstext/105\833.txt.wakati
# data/newstext/105\834.txt.wakati
# data/newstext/105\835.txt.wakati
# data/newstext/105\836.txt.wakati
# data/newstext/105\837.txt.wakati
# data/newstext/105\838.txt.wakati
# data/newstext/105\839.txt.wakati
# data/newstext/105\84.txt.wakati
# data/newstext/105\840.txt.wakati
# data/newstext/105\841.txt.wakati
# data/newstext/105\842.txt.wakati
# data/newstext/105\843.txt.wakati
# data/newstext/105\844.txt.wakati
# data/newstext/105\845.txt.wakati
# data/newstext/105\846.txt.wakati
# data/newstext/105\847.txt.wakati
# data/newstext/105\848.txt.wakati
# data/newstext/105\849.txt.wakati
# data/newstext/105\85.txt.wakati
# data/newstext/105\850.txt.wakati
# data/newstext/105\851.txt.wakati
# data/newstext/105\852.txt.wakati
# data/newstext/105\853.txt.wakati
# data/newstext/105\854.txt.wakati
# data/newstext/105\855.txt.wakati
# data/newstext/105\856.txt.wakati
# data/newstext/105\857.txt.wakati
# data/newstext/105\858.txt.wakati
# data/newstext/105\859.txt.wakati
# data/newstext/105\86.txt.wakati
# data/newstext/105\860.txt.wakati
# data/newstext/105\861.txt.wakati
# data/newstext/105\862.txt.wakati
# data/newstext/105\863.txt.wakati
# data/newstext/105\864.txt.wakati
# data/newstext/105\865.txt.wakati
# data/newstext/105\866.txt.wakati
# data/newstext/105\867.txt.wakati
# data/newstext/105\868.txt.wakati
# data/newstext/105\869.txt.wakati
# data/newstext/105\87.txt.wakati
# data/newstext/105\870.txt.wakati
# data/newstext/105\871.txt.wakati
# data/newstext/105\872.txt.wakati
# data/newstext/105\873.txt.wakati
# data/newstext/105\874.txt.wakati
# data/newstext/105\875.txt.wakati
# data/newstext/105\876.txt.wakati
# data/newstext/105\877.txt.wakati
# data/newstext/105\878.txt.wakati
# data/newstext/105\879.txt.wakati
# data/newstext/105\88.txt.wakati
# data/newstext/105\880.txt.wakati
# data/newstext/105\881.txt.wakati
# data/newstext/105\882.txt.wakati
# data/newstext/105\883.txt.wakati
# data/newstext/105\884.txt.wakati
# data/newstext/105\885.txt.wakati
# data/newstext/105\886.txt.wakati
# data/newstext/105\887.txt.wakati
# data/newstext/105\888.txt.wakati
# data/newstext/105\889.txt.wakati
# data/newstext/105\89.txt.wakati
# data/newstext/105\890.txt.wakati
# data/newstext/105\891.txt.wakati
# data/newstext/105\892.txt.wakati
# data/newstext/105\893.txt.wakati
# data/newstext/105\894.txt.wakati
# data/newstext/105\895.txt.wakati
# data/newstext/105\896.txt.wakati
# data/newstext/105\897.txt.wakati
# data/newstext/105\898.txt.wakati
# data/newstext/105\899.txt.wakati
# data/newstext/105\9.txt.wakati
# data/newstext/105\90.txt.wakati
# data/newstext/105\900.txt.wakati
# data/newstext/105\901.txt.wakati
# data/newstext/105\902.txt.wakati
# data/newstext/105\903.txt.wakati
# data/newstext/105\904.txt.wakati
# data/newstext/105\905.txt.wakati
# data/newstext/105\906.txt.wakati
# data/newstext/105\907.txt.wakati
# data/newstext/105\908.txt.wakati
# data/newstext/105\909.txt.wakati
# data/newstext/105\91.txt.wakati
# data/newstext/105\910.txt.wakati
# data/newstext/105\911.txt.wakati
# data/newstext/105\912.txt.wakati
# data/newstext/105\913.txt.wakati
# data/newstext/105\914.txt.wakati
# data/newstext/105\915.txt.wakati
# data/newstext/105\916.txt.wakati
# data/newstext/105\917.txt.wakati
# data/newstext/105\918.txt.wakati
# data/newstext/105\919.txt.wakati
# data/newstext/105\92.txt.wakati
# data/newstext/105\920.txt.wakati
# data/newstext/105\921.txt.wakati
# data/newstext/105\922.txt.wakati
# data/newstext/105\923.txt.wakati
# data/newstext/105\924.txt.wakati
# data/newstext/105\925.txt.wakati
# data/newstext/105\926.txt.wakati
# data/newstext/105\927.txt.wakati
# data/newstext/105\928.txt.wakati
# data/newstext/105\929.txt.wakati
# data/newstext/105\93.txt.wakati
# data/newstext/105\930.txt.wakati
# data/newstext/105\931.txt.wakati
# data/newstext/105\932.txt.wakati
# data/newstext/105\933.txt.wakati
# data/newstext/105\934.txt.wakati
# data/newstext/105\935.txt.wakati
# data/newstext/105\936.txt.wakati
# data/newstext/105\937.txt.wakati
# data/newstext/105\938.txt.wakati
# data/newstext/105\939.txt.wakati
# data/newstext/105\94.txt.wakati
# data/newstext/105\940.txt.wakati
# data/newstext/105\941.txt.wakati
# data/newstext/105\942.txt.wakati
# data/newstext/105\943.txt.wakati
# data/newstext/105\944.txt.wakati
# data/newstext/105\945.txt.wakati
# data/newstext/105\946.txt.wakati
# data/newstext/105\947.txt.wakati
# data/newstext/105\948.txt.wakati
# data/newstext/105\949.txt.wakati
# data/newstext/105\95.txt.wakati
# data/newstext/105\950.txt.wakati
# data/newstext/105\951.txt.wakati
# data/newstext/105\952.txt.wakati
# data/newstext/105\953.txt.wakati
# data/newstext/105\954.txt.wakati
# data/newstext/105\955.txt.wakati
# data/newstext/105\956.txt.wakati
# data/newstext/105\957.txt.wakati
# data/newstext/105\958.txt.wakati
# data/newstext/105\959.txt.wakati
# data/newstext/105\96.txt.wakati
# data/newstext/105\960.txt.wakati
# data/newstext/105\961.txt.wakati
# data/newstext/105\962.txt.wakati
# data/newstext/105\963.txt.wakati
# data/newstext/105\964.txt.wakati
# data/newstext/105\965.txt.wakati
# data/newstext/105\966.txt.wakati
# data/newstext/105\967.txt.wakati
# data/newstext/105\968.txt.wakati
# data/newstext/105\969.txt.wakati
# data/newstext/105\97.txt.wakati
# data/newstext/105\970.txt.wakati
# data/newstext/105\971.txt.wakati
# data/newstext/105\972.txt.wakati
# data/newstext/105\973.txt.wakati
# data/newstext/105\974.txt.wakati
# data/newstext/105\975.txt.wakati
# data/newstext/105\976.txt.wakati
# data/newstext/105\977.txt.wakati
# data/newstext/105\978.txt.wakati
# data/newstext/105\979.txt.wakati
# data/newstext/105\98.txt.wakati
# data/newstext/105\980.txt.wakati
# data/newstext/105\981.txt.wakati
# data/newstext/105\982.txt.wakati
# data/newstext/105\983.txt.wakati
# data/newstext/105\984.txt.wakati
# data/newstext/105\985.txt.wakati
# data/newstext/105\986.txt.wakati
# data/newstext/105\987.txt.wakati
# data/newstext/105\988.txt.wakati
# data/newstext/105\989.txt.wakati
# data/newstext/105\99.txt.wakati
# data/newstext/105\990.txt.wakati
# data/newstext/105\991.txt.wakati
# data/newstext/105\992.txt.wakati
# data/newstext/105\993.txt.wakati
# data/newstext/105\994.txt.wakati
# data/newstext/105\995.txt.wakati
# data/newstext/105\996.txt.wakati
# data/newstext/105\997.txt.wakati
# data/newstext/105\998.txt.wakati
# data/newstext/105\999.txt.wakati
# ok

# %% [markdown]
# ##### Keras를 이용한 MLP 텍스트 분류

# %%
### 필요한 모듈 import
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import model_selection, metrics
import json

max_words = 77238   # word-dic.json 파일 참고
nb_classes = 6      # 6개의 카테고리
batch_size = 64     # 한 번에 학습할 단어 개수
epochs = 20       # 회차

## MLP 모델 생성하는 함수
def build_model() :
    model = Sequential()
    model.add(Dense(512, input_shape = (max_words,)))   # 단어 개수만큼 행을 가진 행렬로 입력, 출력값 512개
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

## 데이터 읽어오기
# data = json.load(open('data/newstext/data-mini.json'))    # 정답률 = 0.7575757575757576
data = json.load(open('data/newstext/data.json')) 
X = data["X"]   # 텍스트 데이터
Y = data["Y"]   # 카테고리 데이터

# %%
## 학습하기
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

Y_train = np_utils.to_categorical(Y_train, num_classes=nb_classes)      # Y의 숫자를 다시 카테고리화
X_train = np.asarray(X_train)

print(len(X_train),len(Y_train))

model = KerasClassifier(build_fn=build_model, epochs=epochs, batch_size=batch_size)
model.fit(X_train, Y_train)
# Out:
# 13374 13374
# C:\Users\tjoeun709\AppData\Local\Temp\ipykernel_7244\96352554.py:9: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=build_model, epochs=epochs, batch_size=batch_size)
# Epoch 1/20
# 209/209 [==============================] - 44s 161ms/step - loss: 0.4629 - accuracy: 0.8718
# Epoch 2/20
# 209/209 [==============================] - 33s 157ms/step - loss: 0.1715 - accuracy: 0.9554
# Epoch 3/20
# 209/209 [==============================] - 33s 156ms/step - loss: 0.1025 - accuracy: 0.9747
# Epoch 4/20
# 209/209 [==============================] - 32s 154ms/step - loss: 0.0954 - accuracy: 0.9800
# Epoch 5/20
# 209/209 [==============================] - 32s 154ms/step - loss: 0.0755 - accuracy: 0.9838
# Epoch 6/20
# 209/209 [==============================] - 32s 154ms/step - loss: 0.0763 - accuracy: 0.9852
# Epoch 7/20
# 209/209 [==============================] - 32s 155ms/step - loss: 0.0785 - accuracy: 0.9847
# Epoch 8/20
# 209/209 [==============================] - 32s 152ms/step - loss: 0.0788 - accuracy: 0.9871
# Epoch 9/20
# 209/209 [==============================] - 32s 151ms/step - loss: 0.0846 - accuracy: 0.9870
# Epoch 10/20
# 209/209 [==============================] - 32s 152ms/step - loss: 0.0878 - accuracy: 0.9862
# Epoch 11/20
# 209/209 [==============================] - 32s 152ms/step - loss: 0.0869 - accuracy: 0.9864
# Epoch 12/20
# 209/209 [==============================] - 32s 153ms/step - loss: 0.0782 - accuracy: 0.9874
# Epoch 13/20
# 209/209 [==============================] - 32s 151ms/step - loss: 0.0709 - accuracy: 0.9885
# Epoch 14/20
# 209/209 [==============================] - 32s 153ms/step - loss: 0.0711 - accuracy: 0.9888
# Epoch 15/20
# 209/209 [==============================] - 32s 155ms/step - loss: 0.0812 - accuracy: 0.9885
# Epoch 16/20
# 209/209 [==============================] - 32s 152ms/step - loss: 0.0717 - accuracy: 0.9888
# Epoch 17/20
# 209/209 [==============================] - 32s 152ms/step - loss: 0.0785 - accuracy: 0.9887
# Epoch 18/20
# 209/209 [==============================] - 32s 154ms/step - loss: 0.0714 - accuracy: 0.9872
# Epoch 19/20
# 209/209 [==============================] - 33s 159ms/step - loss: 0.0751 - accuracy: 0.9871
# Epoch 20/20
# 209/209 [==============================] - 33s 160ms/step - loss: 0.0834 - accuracy: 0.9886

# %%
## 예측하기
y = model.predict(X_test)
ac_score = metrics.accuracy_score(Y_test, y)
cl_report = metrics.classification_report(Y_test, y)
print('정답률 =', ac_score)
print('리포트 =\n', cl_report)
# Out:
# 140/140 [==============================] - 7s 27ms/step
# 정답률 = 0.8869701726844584
# 리포트 =
#                precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93      1013
#            1       0.83      0.93      0.88       858
#            2       0.88      0.85      0.86       500
#            3       0.85      0.92      0.88       686
#            4       0.89      0.88      0.89       889
#            5       0.94      0.77      0.85       513
#
#     accuracy                           0.89      4459
#    macro avg       0.89      0.88      0.88      4459
# weighted avg       0.89      0.89      0.89      4459
